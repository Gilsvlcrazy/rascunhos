# %% [markdown]
# $y = \cos(\omega t)$

# %%
def funcaoCosseno(t, omega=1):
    return np.cos(omega*t)

import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0,10,.5)
y = funcaoCosseno(t)
y = np.cos(1*t)

np.convolve

plt.figure(figsize=(15,4))
plt.stem(t, y);
plt.show()
